# %%
# %%time
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from linreg import LinearModel
# Out:
# CPU times: user 767 ms, sys: 344 ms, total: 1.11 s
# Wall time: 1.13 s

# %%
#Explicitly specified the xlrd engine
df = pd.read_excel('chirps.xls', engine='xlrd')
df.head()
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'iso-8859-1'
#            X          Y
# 0  20.000000  88.599998
# 1  16.000000  71.599998
# 2  19.799999  93.300003
# 3  18.400000  84.300003
# 4  17.100000  80.599998

# %%
x = df.X.values
y = df.Y.values
x = np.reshape(x, (x.shape[0], 1))
y = np.reshape(y, (y.shape[0], 1))

# %%
model = LinearModel(1)

losses = model.train(
    x, y,
    200, 0.0001
)
# Out:
# Iter: 0, Current loss: 2384.3502
# Iter: 20, Current loss: 769.0628
# Iter: 40, Current loss: 252.5707
# Iter: 60, Current loss: 87.4211
# Iter: 80, Current loss: 34.6140
# Iter: 100, Current loss: 17.7287
# Iter: 120, Current loss: 12.3295
# Iter: 140, Current loss: 10.6030
# Iter: 160, Current loss: 10.0509
# Iter: 180, Current loss: 9.8742

# %%
plt.plot(losses);

# %%
y_preds = model.forward_pass(x)

# %%
plt.plot(y_preds, y, 'r.');

# %%
print(model.W, model.b)
# Out:
# [[4.86477749]] -1.4608092094946352
